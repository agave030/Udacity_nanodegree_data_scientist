# %% [markdown]
# ## The Description from Udacity
# For this project, you will pick a dataset. Inspired by Robert, there are a few public datasets from AirBnB available below, but you may also choose a dataset similar to what was used in the lessons, or an entirely different dataset. Using your dataset, you will choose 3 questions you aspire to answer from the data.
#
# 1. Pick a dataset.
#
# 2. Pose at least three questions related to business or real-world applications of how the data could be used.
#
# 3. Create a Jupyter Notebook, using any associated packages you'd like, to:
#     - Prepare data:
#         - Gather necessary data to answer your questions
#         - Handle categorical and missing data
#         - Provide insight into the methods you chose and why you chose them
#     - Analyze, Model, and Visualize
#         - Provide a clear connection between your business questions and how the data answers them.
# 4. Communicate your business insights:
#
# - Create a Github repository to share your code and data wrangling/modeling techniques, with a technical audience in mind.
# - Create a blog post to share your questions and insights with a non-technical audience.
#
# Your deliverables will be a Github repo and a blog post. Use the rubric here to assist in successfully completing this project!

# %% [markdown]
# ### CRISP-DM — Cross Industry Process for Data Mining
# 1. Business Understanding
#     - This means understanding the problem and questions you are interested in tackling in the context of whatever domain you're working in.
# 2. Data Understanding:
#     - At this step, you need to move the questions from Business Understanding to data. You might already have data that could be used to answer the questions, or you might have to collect data to get at your questions of interest.
# 3. Prepare Data
# 4. Data Modeling
# 5. Evaluate the Results
# 6. Deploy

# %% [markdown]
# ## The Description from Kaggle (Data Resource)
#
# Since 2008, guests and hosts have used Airbnb to travel in a more unique, personalized way. As part of the Airbnb Inside initiative, this dataset describes the listing activity of homestays in Seattle, WA.
#
# Content
# The following Airbnb activity is included in this Seattle dataset:
#
# - Listings, including full descriptions and average review score
# - Reviews, including unique id for each reviewer and detailed comments
# - Calendar, including listing id and the price and availability for that day

# %% [markdown]
# # Business understanding:
# ### 1. What's the correlation between location and Airbnb?
#     - We're going to dig into the correlation between airbnb itself and its location. I'm going to obtain the Seattle international airport's latitude and longitude and compare it with the certain airbnb's latitude and longitude. Then we can calculate the absolute distance.(It's going to use lots of math.) As mentioned above, we're going to visualize the data. X-axis is price from listings.csv. Y-axis is distance from we just calculated. We can observe the correlation by this plot.
# ### 2. Can we predict the price from these factors?
#     - Here I'm trying to analyzing the factors I choose from scratch(Excluding latitude and logitude. You'll see the reason later.) After filtering the data from listing.csv, I choose 10 columns as factors. First, I'll convert the categorical data to numeric data. Second, I'll use Lasso as my estimator in machine learning. Then I'll evaluate and tuning my model. After all, I'll use the test set to verify my assumption.
# ### 3. What factor highly affect the price?
#     - After predicting the price, I'll observe the correlation between two variables. By plotting the image, it can show which factor influence more than other variables.

# %% [markdown]
# ### Then, let's get started...

# %%
# import package
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # First Step: Data understanding. Try to dig into the data.

# %%
# file loading
calendar = pd.read_csv("Seattle AirBNB Data/calendar.csv")
listing = pd.read_csv("Seattle AirBNB Data/listings.csv")
reviews = pd.read_csv("Seattle AirBNB Data/reviews.csv")

# %%
# observation
listing.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %% [markdown]
# # Question 1: What's the correlation between location and Airbnb?
# - I'll set Seattle-Tacoma International Airport as the center. By getting its latitude and longtitude, I can calculate the distance between the airbnb's location and the airport.

# %%
listing[['id', 'price', 'latitude', 'longitude']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         3818 non-null   int64
#  1   price      3818 non-null   object
#  2   latitude   3818 non-null   float64
#  3   longitude  3818 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 119.4+ KB

# %%
listing[['id', 'price', 'latitude', 'longitude']].head()
# Out:
#         id    price   latitude   longitude
# 0   241032   $85.00  47.636289 -122.371025
# 1   953595  $150.00  47.639123 -122.365666
# 2  3308979  $975.00  47.629724 -122.369483
# 3  7421966  $100.00  47.638473 -122.369279
# 4   278830  $450.00  47.632918 -122.372471

# %% [markdown]
# By the data above, we can observe the 'price' column is an object. We need to convert it to float and remove the dollar sign.

# %% [markdown]
# # Second Step: prepare data.

# %%
# variable definition
tacoma_airport = [47.440521, -122.296082]
distance = []

# %%
# convert the dollar sign and the decimal point to normal number, also convert the type(object) to float
listing['price'] = (listing['price'].replace('[\$,)]', '', regex=True).replace('[(]', '-', regex=True)).astype(float)

# %%
listing[['id', 'price', 'latitude', 'longitude']].head()
# Out:
#         id  price   latitude   longitude
# 0   241032   85.0  47.636289 -122.371025
# 1   953595  150.0  47.639123 -122.365666
# 2  3308979  975.0  47.629724 -122.369483
# 3  7421966  100.0  47.638473 -122.369279
# 4   278830  450.0  47.632918 -122.372471

# %% [markdown]
# We successfully convert the price from object to float, and remove the dollar sign.

# %%
np.sum(listing['price'].isnull())
# Out:
# 0

# %% [markdown]
# Here we can find that the price column doesn't have any NaN value.

# %%
listing['price'].describe()
# Out:
# count    3818.000000
# mean      127.976166
# std        90.250022
# min        20.000000
# 25%        75.000000
# 50%       100.000000
# 75%       150.000000
# max      1000.000000
# Name: price, dtype: float64

# %% [markdown]
# We could find the outlier by the following:
# 1. mean +/- 3 standard deviation
# 2. box plot
#
# Here we choose first way to observe and remove outlier.

# %%
# We're using the price column and there's no NaN value.
# No need to data cleaning.
# Now we're going to remove outlier by calculating mean +/- 3 std.
# I define an empty list(delete) for appending the outlier value, so we can drop it.

delete = []
for i in range(len(listing['price'])):
    if listing['price'].iloc[i] > (listing['price'].mean() + 3 * listing['price'].std()) or listing['price'].iloc[i] < (listing['price'].mean() - 3 * listing['price'].std()):
        delete.append(listing['price'].index[i])
listing = listing.drop(delete)

# %%
listing['price'].describe()
# Out:
# count    3737.000000
# mean      119.405941
# std        66.118687
# min        20.000000
# 25%        75.000000
# 50%       100.000000
# 75%       150.000000
# max       395.000000
# Name: price, dtype: float64

# %% [markdown]
# We can calculate the result is right or wrong by mean plus three standard deviation, that is, `128 + 90 * 3 = 398`. The maximum value is 395. Now there's no outlier.
# <br>
# Then, we're going to calculate the distance from airbnb to airport. First, we define a function for converting the latitude and longitude to absolute distance.

# %%
def getDistance(latA, lonA, latB, lonB):
    ra = 6378140  # radius of equator: meter
    rb = 6356755  # radius of polar: meter
    flatten = (ra - rb) / ra  # Partial rate of the earth
    # change angle to radians
    radLatA = math.radians(latA)
    radLonA = math.radians(lonA)
    radLatB = math.radians(latB)
    radLonB = math.radians(lonB)

    pA = math.atan(rb / ra * math.tan(radLatA))
    pB = math.atan(rb / ra * math.tan(radLatB))
    x = math.acos(math.sin(pA) * math.sin(pB) + math.cos(pA) * math.cos(pB) * math.cos(radLonA - radLonB))
    c1 = (math.sin(x) - x) * (math.sin(pA) + math.sin(pB)) ** 2 / math.cos(x / 2) ** 2
    c2 = (math.sin(x) + x) * (math.sin(pA) - math.sin(pB)) ** 2 / math.sin(x / 2) ** 2
    dr = flatten / 8 * (c1 - c2)
    distance = ra * (x + dr)
    distance = round(distance / 1000, 6)
    return distance

# %% [markdown]
# ![%E6%88%AA%E5%9C%96%202021-05-26%20%E4%B8%8B%E5%8D%8812.51.33.png](attachment:%E6%88%AA%E5%9C%96%202021-05-26%20%E4%B8%8B%E5%8D%8812.51.33.png)

# %% [markdown]
# d is distance between two poing. f = flatten. latA = Phi1, lonA = lambda1, latB =phi2, lonB = lambda2. The latitude and longitude need to be converted into radian.

# %%
for index in range(len(listing)):
    distance.append(getDistance(tacoma_airport[0], tacoma_airport[1], listing['latitude'].iloc[index], listing['longitude'].iloc[index]))

# %%
type(distance)
# Out:
# list

# %% [markdown]
# The unit of distance is kilometer.

# %%
# visualizing
# price / accomodates means price per person
plt.scatter(listing['price'], distance, s=3)
plt.xlabel("Price")
plt.ylabel("Absolute Distance (km)")
plt.title("Relation between price and distance");

# %% [markdown]
# As you can see, the y axis is absolute distance. It was calculated by latitude and longitude.
# We got a conclusion, that is, the distance and the price don't have positive correlation. It goes against our intuition. The closer doesn't mean more expensive.

# %% [markdown]
# # Q2: Can we predict the price from these factors?
# 1. filter the data from listing.csv, I choose 10 columns as factors.
# 2. I'll convert the categorical data to numeric data.
# 3. I'll use Lasso as my estimator in machine learning(Because of this map: https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html.)
# 4. I'll evaluate and tuning my model. After all, I'll use the validation set to verify my assumption.

# %%
listing_prediction = listing[['id', 'host_is_superhost', 'host_has_profile_pic', 'property_type', 'room_type', 'bed_type', 'number_of_reviews', 'review_scores_rating', 'cancellation_policy', 'price']]

listing_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3737 entries, 0 to 3817
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3737 non-null   int64
#  1   host_is_superhost     3735 non-null   object
#  2   host_has_profile_pic  3735 non-null   object
#  3   property_type         3736 non-null   object
#  4   room_type             3737 non-null   object
#  5   bed_type              3737 non-null   object
#  6   number_of_reviews     3737 non-null   int64
#  7   review_scores_rating  3110 non-null   float64
#  8   cancellation_policy   3737 non-null   object
#  9   price                 3737 non-null   float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 481.1+ KB

# %%
np.sum(listing_prediction.isnull())
# Out:
# id                        0
# host_is_superhost         2
# host_has_profile_pic      2
# property_type             1
# room_type                 0
# bed_type                  0
# number_of_reviews         0
# review_scores_rating    627
# cancellation_policy       0
# price                     0
# dtype: int64

# %%
listing_prediction = listing_prediction.dropna(subset=['host_is_superhost', 'host_has_profile_pic', 'property_type'])
np.sum(listing_prediction.isnull())
# Out:
# id                        0
# host_is_superhost         0
# host_has_profile_pic      0
# property_type             0
# room_type                 0
# bed_type                  0
# number_of_reviews         0
# review_scores_rating    624
# cancellation_policy       0
# price                     0
# dtype: int64

# %%
# Create X (all the feature columns)
X = listing_prediction.drop('price', axis=1)

# Create Y (the target column)
y = listing_prediction['price']

# %%
X.head()
# Out:
#         id host_is_superhost host_has_profile_pic property_type  \
# 0   241032                 f                    t     Apartment
# 1   953595                 t                    t     Apartment
# 3  7421966                 f                    t     Apartment
# 5  5956968                 f                    t         House
# 6  1909058                 t                    t         House
#
#          room_type  bed_type  number_of_reviews  review_scores_rating  \
# 0  Entire home/apt  Real Bed                207                  95.0
# 1  Entire home/apt  Real Bed                 43                  96.0
# 3  Entire home/apt  Real Bed                  0                   NaN
# 5     Private room  Real Bed                 17                  95.0
# 6     Private room  Real Bed                 58                  99.0
#
#   cancellation_policy
# 0            moderate
# 1              strict
# 3            flexible
# 5              strict
# 6            moderate

# %%
y.head()
# Out:
# 0     85.0
# 1    150.0
# 3    100.0
# 5    120.0
# 6     80.0
# Name: price, dtype: float64

# %% [markdown]
# Now, we're going to convert the t/f to 0/1(for 'host_is_superhost', 'host_has_profile_pic')
#
# Count the value of categorical data(for property_type, room_type, bed_type, cancellation_policy)
#
# Fill the NaN value.

# %%
mapping = {'t': 0, 'f': 1}
X['host_is_superhost'] = X['host_is_superhost'].map(mapping)
X['host_has_profile_pic'] = X['host_has_profile_pic'].map(mapping)
X.head()
# Out:
#         id  host_is_superhost  host_has_profile_pic property_type  \
# 0   241032                  1                     0     Apartment
# 1   953595                  0                     0     Apartment
# 3  7421966                  1                     0     Apartment
# 5  5956968                  1                     0         House
# 6  1909058                  0                     0         House
#
#          room_type  bed_type  number_of_reviews  review_scores_rating  \
# 0  Entire home/apt  Real Bed                207                  95.0
# 1  Entire home/apt  Real Bed                 43                  96.0
# 3  Entire home/apt  Real Bed                  0                   NaN
# 5     Private room  Real Bed                 17                  95.0
# 6     Private room  Real Bed                 58                  99.0
#
#   cancellation_policy
# 0            moderate
# 1              strict
# 3            flexible
# 5              strict
# 6            moderate

# %% [markdown]
# Great! Now we convert the t and f to 0 and 1. Let's see the categorical data. I'll convert it by Scikit-Learn.

# %%
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
X['property_type'] = ord_enc.fit_transform(X[['property_type']])
X['room_type'] = ord_enc.fit_transform(X[['room_type']])
X['bed_type'] = ord_enc.fit_transform(X[['bed_type']])
X['cancellation_policy'] = ord_enc.fit_transform(X[['cancellation_policy']])

# %%
X.head()
# Out:
#         id  host_is_superhost  host_has_profile_pic  property_type  room_type  \
# 0   241032                  1                     0            0.0        0.0
# 1   953595                  0                     0            0.0        0.0
# 3  7421966                  1                     0            0.0        0.0
# 5  5956968                  1                     0            9.0        1.0
# 6  1909058                  0                     0            9.0        1.0
#
#    bed_type  number_of_reviews  review_scores_rating  cancellation_policy
# 0       4.0                207                  95.0                  1.0
# 1       4.0                 43                  96.0                  2.0
# 3       4.0                  0                   NaN                  0.0
# 5       4.0                 17                  95.0                  2.0
# 6       4.0                 58                  99.0                  1.0

# %% [markdown]
# Let's fill the NaN value with 0 in review_scores_rating columns.

# %%
np.sum(X['review_scores_rating'].isnull())
# Out:
# 624

# %%
X['review_scores_rating'] = X['review_scores_rating'].fillna(0)

# %%
X.head()
# Out:
#         id  host_is_superhost  host_has_profile_pic  property_type  room_type  \
# 0   241032                  1                     0            0.0        0.0
# 1   953595                  0                     0            0.0        0.0
# 3  7421966                  1                     0            0.0        0.0
# 5  5956968                  1                     0            9.0        1.0
# 6  1909058                  0                     0            9.0        1.0
#
#    bed_type  number_of_reviews  review_scores_rating  cancellation_policy
# 0       4.0                207                  95.0                  1.0
# 1       4.0                 43                  96.0                  2.0
# 3       4.0                  0                   0.0                  0.0
# 5       4.0                 17                  95.0                  2.0
# 6       4.0                 58                  99.0                  1.0

# %%
np.sum(X.isnull())
# Out:
# id                      0
# host_is_superhost       0
# host_has_profile_pic    0
# property_type           0
# room_type               0
# bed_type                0
# number_of_reviews       0
# review_scores_rating    0
# cancellation_policy     0
# dtype: int64

# %% [markdown]
# # Third step: Data modeling.

# %%
# Import the Ridge model class from the linear_model module
from sklearn.linear_model import Ridge

# Setup random seed
np.random.seed(0)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Institate and fit the model (on the training set)
model = Ridge()
model.fit(X_train, y_train)

# Check the score of the model (on the test set)
model.score(X_test, y_test)
# Out:
# 0.31542192713373773

# %% [markdown]
# # Q3: Does it have busy season? If have, is it more expensive than usual?

# %%
# reload the file to refresh the record
calendar = pd.read_csv("Seattle AirBNB Data/calendar.csv")

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1393570 non-null  int64
#  1   date        1393570 non-null  object
#  2   available   1393570 non-null  object
#  3   price       934542 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 42.5+ MB

# %%
calendar.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %% [markdown]
# For analyzing the busy season, I'm about to do the following:
# 1. convert the 'available' columns' t/f to 0/1
# 2. calculate the total of a day of availability by adding all airbnbs' data
# 3. visualizing it

# %%
# convert the 'available' columns' t/f to 0/1
available_mapping = {'t': 0, 'f': 1}
calendar['available'] = calendar['available'].map(available_mapping)

calendar
# Out:
#          listing_id        date  available   price
# 0            241032  2016-01-04          0  $85.00
# 1            241032  2016-01-05          0  $85.00
# 2            241032  2016-01-06          1     NaN
# 3            241032  2016-01-07          1     NaN
# 4            241032  2016-01-08          1     NaN
# ...             ...         ...        ...     ...
# 1393565    10208623  2016-12-29          1     NaN
# 1393566    10208623  2016-12-30          1     NaN
# 1393567    10208623  2016-12-31          1     NaN
# 1393568    10208623  2017-01-01          1     NaN
# 1393569    10208623  2017-01-02          1     NaN
#
# [1393570 rows x 4 columns]

# %%
calendar['date'] = pd.to_datetime(calendar['date'])
availability = calendar.set_index('date').groupby(pd.Grouper(freq='d')).mean()
availability = availability.reset_index()
availability
# Out:
#           date    listing_id  available
# 0   2016-01-04  5.550111e+06   0.545574
# 1   2016-01-05  5.550111e+06   0.511001
# 2   2016-01-06  5.550111e+06   0.521739
# 3   2016-01-07  5.550111e+06   0.534835
# 4   2016-01-08  5.550111e+06   0.533263
# ..         ...           ...        ...
# 360 2016-12-29  5.550111e+06   0.257465
# 361 2016-12-30  5.550111e+06   0.256155
# 362 2016-12-31  5.550111e+06   0.251179
# 363 2017-01-01  5.550111e+06   0.234678
# 364 2017-01-02  5.550111e+06   0.272918
#
# [365 rows x 3 columns]

# %%
font = {'family' : 'monospace',
        'weight' : 'bold',
        'size'   : 22}
mlt.rc('font', **font)

plt.figure(figsize=(20, 10))
plt.plot(availibility['date'], availibility['available'])

plt.show()

# %% [markdown]
# As we can observe, January and July are busy season. Now we're trying to analyze the monthly price.

# %%
# here we're going to convert the price to integer
calendar.price = calendar.price.fillna('$0.00')
calendar.price = calendar['price'].replace('[\$,)]','', regex=True).replace('[(]','-', regex=True).astype(float)
calendar.price
# Out:
# 0          85.0
# 1          85.0
# 2           0.0
# 3           0.0
# 4           0.0
#            ...
# 1393565     0.0
# 1393566     0.0
# 1393567     0.0
# 1393568     0.0
# 1393569     0.0
# Name: price, Length: 1393570, dtype: float64

# %%
price_avg = calendar.set_index('date').groupby(pd.Grouper(freq='d')).sum()
price_avg = price_avg.reset_index()
price_avg
# Out:
#           date       index   listing_id  available     price
# 0   2016-01-04  2659628345  21190325396       2083  211819.0
# 1   2016-01-05  2659632163  21190325396       1951  225312.0
# 2   2016-01-06  2659635981  21190325396       1992  220815.0
# 3   2016-01-07  2659639799  21190325396       2042  214823.0
# 4   2016-01-08  2659643617  21190325396       2036  227456.0
# ..         ...         ...          ...        ...       ...
# 360 2016-12-29  2661002825  21190325396        983  391359.0
# 361 2016-12-30  2661006643  21190325396        978  411057.0
# 362 2016-12-31  2661010461  21190325396        959  416551.0
# 363 2017-01-01  2661014279  21190325396        896  403607.0
# 364 2017-01-02  2661018097  21190325396       1042  376350.0
#
# [365 rows x 5 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(price_avg['date'], price_avg['price'])

plt.show()

# %% [markdown]
# (I'm not sure my analysis is right or wrong)
# As we can see, January haas the lowest price. It can explain why the January is the busy season.
